# %% [markdown]
# # Ejemplo de perfilamiento de datos con pandas profiling
#
# Descargue los datos de properati para Colombia.
# Página oficial:
# https://www.properati.com.co/data/
#
# Url descarga:
# https://storage.googleapis.com/properati-data-public/co_properties.csv.gz
#
# Descomprima el archivo .gz

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
csv_path = r"C:\opt\work\igac\git\ejemplo_data_engineering\data\co_properties.csv"
df = pd.read_csv(csv_path)  
df.shape
# Out:
# (1000000, 25)

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
#        'title', 'description', 'property_type', 'operation_type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                  object
# ad_type             object
# start_date          object
# end_date            object
# created_on          object
# lat                float64
# lon                float64
# l1                  object
# l2                  object
# l3                  object
# l4                  object
# l5                  object
# l6                  object
# rooms              float64
# bedrooms           float64
# bathrooms          float64
# surface_total      float64
# surface_covered    float64
# price              float64
# currency            object
# price_period        object
# title               object
# description         object
# property_type       object
# operation_type      object
# dtype: object

# %%
df.head()
# Out:
#                          id    ad_type  start_date    end_date  created_on  \
# 0  KsjahK62rxcYKXXQjOdkqw==  Propiedad  2020-10-07  2021-10-09  2020-10-07
# 1  Y+gsBZYq1zu5NoR3V5oUGA==  Propiedad  2020-10-07  2021-01-06  2020-10-07
# 2  Jpzqxj8/Vgf3Aa5ASxUBNg==  Propiedad  2020-10-07  2020-10-07  2020-10-07
# 3  ieuFnkFx/yHDD66iMV14Gw==  Propiedad  2020-10-07  2021-04-12  2020-10-07
# 4  g4u5JM+hAHEk8SukRSjMzg==  Propiedad  2020-10-07  9999-12-31  2020-10-07
#
#       lat        lon        l1               l2    l3  ... bathrooms  \
# 0  3.9210 -76.506000  Colombia  Valle del Cauca   NaN  ...       7.0
# 1  3.3577 -76.541811  Colombia  Valle del Cauca  Cali  ...       7.0
# 2  3.3577 -76.541811  Colombia  Valle del Cauca  Cali  ...       7.0
# 3  3.3640 -76.538000  Colombia  Valle del Cauca  Cali  ...       8.0
# 4  3.3910 -76.517000  Colombia  Valle del Cauca  Cali  ...       9.0
#
#   surface_total surface_covered         price  currency  price_period  \
# ...

# %%
df.tail()
# Out:
#                               id    ad_type  start_date    end_date  \
# 999995  HogfsSTtBvNDJkf98/FGIw==  Propiedad  2021-03-31  2021-05-18
# 999996  1LxE1UMbfMeW5Dv/z4rqJA==  Propiedad  2021-03-31  2021-05-18
# 999997  NEIrzJXLpHqPDIXwD+9r8w==  Propiedad  2021-03-31  2021-05-07
# 999998  fpxqXlGPqDwKhuZVQGxCPA==  Propiedad  2021-03-31  9999-12-31
# 999999  ZU6bNwudfah9N7ma06509Q==  Propiedad  2021-03-31  9999-12-31
#
#         created_on        lat        lon        l1         l2            l3  \
# 999995  2021-03-31   6.186412 -75.658630  Colombia  Antioquia      Medellín
# 999996  2021-03-31   6.186412 -75.658630  Colombia  Antioquia      Medellín
# 999997  2021-03-31   6.186412 -75.658630  Colombia  Antioquia      Medellín
# 999998  2021-03-31  11.015336 -74.831347  Colombia  Atlántico  Barranquilla
# 999999  2021-03-31  11.017029 -74.834101  Colombia  Atlántico  Barranquilla
#
#         ... bathrooms surface_total surface_covered        price  currency  \
# ...

# %%
profile = ProfileReport(df)
html_report = r"C:\opt\work\igac\git\ejemplo_data_engineering\reports\co_properties.csv.report.html"
profile.to_file(html_report)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\apps\miniconda3\envs\python_observatorio\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
